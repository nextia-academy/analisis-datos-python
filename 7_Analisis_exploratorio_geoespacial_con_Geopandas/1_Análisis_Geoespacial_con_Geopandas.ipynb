# %% [markdown]
# # Análisis Geoespacial con Geopandas
#
# ¿Alguna vez te has preguntadoo cómo se hacen las gráficas que muestran variables de datos plasmadas en un mapa geográfico? Estas visualizaciones se utilizan comunmente para expresar datos de cambios globales en salud, población, educación, cultura, violencia, poder político, tecnoligía, entre otros. Estas visualizacioens nos ayudan a entender fácilmente cómo y por qué el mundo ha cambiado a través del tiempo. Para mí, los mapas con datos fueron lo primero del campo del análisis de datos que cautivó mi atención.
#
# Una de las visualizaciones con mapas más útiles que podemos hacer es un mapa de calor. En un mapa de calor, se muestran territorios geográficos coloreados por alguna variable de interés. Los terriotorios pueden ser continentes, países, estados, colonias y hasta manzanas.
#
# Vamos a crear un mapa de calor de obesidad en adultos de 1975 a 2016.
#
# ## Datos
# Descarga el shapefile de países [aquí](https://www.naturalearthdata.com/http//www.naturalearthdata.com/download/110m/cultural/ne_110m_admin_0_countries.zip)
#
# Posteriormente, en [Our World in Data](https://ourworldindata.org/obesity) se encuentran los datos de obesisdad en todos los países del año 1975 al 2016.
#
# ## Instala geopandas
#
# ~~~~bash
# pip3 install --user geopandas
# ~~~~
#
# o
#
# ~~~~bash
# pip install --user geopandas
# ~~~~
#
# o
#
# ~~~~bash
# python -m pip install --user pandas
# ~~~~

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
plt.rcParams['figure.figsize'] = [10, 10]

# %%
shapefile = 'datos/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp'

# %%
gdf = gpd.read_file(shapefile)

# %%
gdf.shape
# Out:
# (177, 95)

# %%
gdf.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE                        ADMIN ADM0_A3  \
# 0         0      2  Sovereign country                         Fiji     FJI
# 1         0      2  Sovereign country  United Republic of Tanzania     TZA
# 2         0      2      Indeterminate               Western Sahara     SAH
# 3         0      2  Sovereign country                       Canada     CAN
# 4         1      2            Country     United States of America     USA
#
#    ...  NAME_KO                       NAME_NL            NAME_PL  \
# 0  ...       피지                          Fiji              Fidżi
# 1  ...     탄자니아                      Tanzania           Tanzania
# 2  ...     서사하라             Westelijke Sahara   Sahara Zachodnia
# 3  ...      캐나다                        Canada             Kanada
# 4  ...       미국  Verenigde Staten van Amerika  Stany Zjednoczone
#
#            NAME_PT                    NAME_RU     NAME_SV  \
# 0             Fiji                      Фиджи        Fiji
# 1         Tanzânia                   Танзания    Tanzania
# 2  Saara Ocidental            Западная Сахара  Västsahara
# 3           Canadá                     Канада      Kanada
# 4   Estados Unidos  Соединённые Штаты Америки         USA
#
#                        NAME_TR     NAME_VI NAME_ZH  \
# 0                         Fiji        Fiji      斐濟
# 1                     Tanzanya    Tanzania    坦桑尼亚
# 2                   Batı Sahra  Tây Sahara    西撒哈拉
# 3                       Kanada      Canada     加拿大
# 4  Amerika Birleşik Devletleri      Hoa Kỳ      美国
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....
#
# [5 rows x 95 columns]

# %% [markdown]
# Leamos únicamente unas cuantas columnas

# %%
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]
gdf.head()
# Out:
#                          ADMIN ADM0_A3  \
# 0                         Fiji     FJI
# 1  United Republic of Tanzania     TZA
# 2               Western Sahara     SAH
# 3                       Canada     CAN
# 4     United States of America     USA
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %%
gdf.plot()

# %%
gdf.rename(columns={'ADMIN':'country', 'ADM0_A3':'code'}, inplace=True)

# %%
gdf.head()
# Out:
#                        country code  \
# 0                         Fiji  FJI
# 1  United Republic of Tanzania  TZA
# 2               Western Sahara  SAH
# 3                       Canada  CAN
# 4     United States of America  USA
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %%
gdf[gdf.code=='BRA'].plot()

# %%
gdf[gdf.country=='Antarctica']
# Out:
#         country code                                           geometry
# 159  Antarctica  ATA  (POLYGON ((-48.66061601418252 -78.047018731598...

# %%
gdf.loc[159]
# Out:
# country                                            Antarctica
# code                                                      ATA
# geometry    (POLYGON ((-48.66061601418252 -78.047018731598...
# Name: 159, dtype: object

# %%
gdf.drop(159, inplace=True)

# %%
gdf[gdf.country=='Antarctica']
# Out:
# Empty GeoDataFrame
# Columns: [country, code, geometry]
# Index: []

# %%
gdf.plot()

# %% [markdown]
# Ahora imporemos el csv de obesidad

# %%
obesity_data = 'datos/share-of-adults-defined-as-obese.csv'

# %%
df = pd.read_csv(obesity_data)

# %%
df.head()
# Out:
#         Entity Code  Year  Share of adults who are obese (%)
# 0  Afghanistan  AFG  1975                                0.5
# 1  Afghanistan  AFG  1976                                0.5
# 2  Afghanistan  AFG  1977                                0.6
# 3  Afghanistan  AFG  1978                                0.6
# 4  Afghanistan  AFG  1979                                0.6

# %%
df[df.Code=='MEX'].tail()
# Out:
#       Entity Code  Year  Share of adults who are obese (%)
# 4825  Mexico  MEX  2012                               26.8
# 4826  Mexico  MEX  2013                               27.3
# 4827  Mexico  MEX  2014                               27.8
# 4828  Mexico  MEX  2015                               28.3
# 4829  Mexico  MEX  2016                               28.9

# %% [markdown]
# Limpiar columnas

# %%
df.columns = ['country', 'code', 'year', 'share_adults_obese']

# %%
df.head()
# Out:
#        country code  year  share_adults_obese
# 0  Afghanistan  AFG  1975                 0.5
# 1  Afghanistan  AFG  1976                 0.5
# 2  Afghanistan  AFG  1977                 0.6
# 3  Afghanistan  AFG  1978                 0.6
# 4  Afghanistan  AFG  1979                 0.6

# %% [markdown]
# Otra forma de leer los datos y asignar el nombre de las columnas que nosotros queramos

# %%
#df = pd.read_csv(obesity_data, names = ['entity', 'code', 'year', 'share_adults_obese'], skiprows = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8316 entries, 0 to 8315
# Data columns (total 4 columns):
# country               8316 non-null object
# code                  7980 non-null object
# year                  8316 non-null int64
# share_adults_obese    8316 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 260.0+ KB

# %%
df[df.code.isna()]
# Out:
#               country code  year  share_adults_obese
# 42             Africa  NaN  1975                 2.0
# 43             Africa  NaN  1976                 2.1
# 44             Africa  NaN  1977                 2.2
# 45             Africa  NaN  1978                 2.3
# 46             Africa  NaN  1979                 2.3
# 47             Africa  NaN  1980                 2.5
# 48             Africa  NaN  1981                 2.6
# 49             Africa  NaN  1982                 2.7
# 50             Africa  NaN  1983                 2.8
# 51             Africa  NaN  1984                 2.9
# 52             Africa  NaN  1985                 3.1
# 53             Africa  NaN  1986                 3.2
# 54             Africa  NaN  1987                 3.4
# 55             Africa  NaN  1988                 3.5
# 56             Africa  NaN  1989                 3.7
# 57             Africa  NaN  1990                 3.9
# 58             Africa  NaN  1991                 4.0
# 59             Africa  NaN  1992                 4.2
# 60             Africa  NaN  1993                 4.4
# 61             Africa  NaN  1994                 4.6
# 62             Africa  NaN  1995                 4.8
# 63             Africa  NaN  1996                 5.1
# 64             Africa  NaN  1997                 5.3
# 65             Africa  NaN  1998                 5.5
# 66             Africa  NaN  1999                 5.8
# 67             Africa  NaN  2000                 6.0
# 68             Africa  NaN  2001                 6.2
# 69             Africa  NaN  2002                 6.5
# 70             Africa  NaN  2003                 6.7
# 71             Africa  NaN  2004                 7.0
# ...               ...  ...   ...                 ...
# 8160  Western Pacific  NaN  1987                 1.3
# 8161  Western Pacific  NaN  1988                 1.4
# 8162  Western Pacific  NaN  1989                 1.5
# 8163  Western Pacific  NaN  1990                 1.6
# 8164  Western Pacific  NaN  1991                 1.7
# 8165  Western Pacific  NaN  1992                 1.7
# 8166  Western Pacific  NaN  1993                 1.8
# 8167  Western Pacific  NaN  1994                 1.9
# 8168  Western Pacific  NaN  1995                 2.1
# 8169  Western Pacific  NaN  1996                 2.2
# 8170  Western Pacific  NaN  1997                 2.3
# 8171  Western Pacific  NaN  1998                 2.4
# 8172  Western Pacific  NaN  1999                 2.5
# 8173  Western Pacific  NaN  2000                 2.7
# 8174  Western Pacific  NaN  2001                 2.8
# 8175  Western Pacific  NaN  2002                 3.0
# 8176  Western Pacific  NaN  2003                 3.2
# 8177  Western Pacific  NaN  2004                 3.3
# 8178  Western Pacific  NaN  2005                 3.5
# 8179  Western Pacific  NaN  2006                 3.7
# 8180  Western Pacific  NaN  2007                 4.0
# 8181  Western Pacific  NaN  2008                 4.2
# 8182  Western Pacific  NaN  2009                 4.4
# 8183  Western Pacific  NaN  2010                 4.7
# 8184  Western Pacific  NaN  2011                 4.9
# 8185  Western Pacific  NaN  2012                 5.2
# 8186  Western Pacific  NaN  2013                 5.5
# 8187  Western Pacific  NaN  2014                 5.8
# 8188  Western Pacific  NaN  2015                 6.1
# 8189  Western Pacific  NaN  2016                 6.4
#
# [336 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# country                 0
# code                  336
# year                    0
# share_adults_obese      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7980 entries, 0 to 8315
# Data columns (total 4 columns):
# country               7980 non-null object
# code                  7980 non-null object
# year                  7980 non-null int64
# share_adults_obese    7980 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 311.7+ KB

# %%
df.head()
# Out:
#        country code  year  share_adults_obese
# 0  Afghanistan  AFG  1975                 0.5
# 1  Afghanistan  AFG  1976                 0.5
# 2  Afghanistan  AFG  1977                 0.6
# 3  Afghanistan  AFG  1978                 0.6
# 4  Afghanistan  AFG  1979                 0.6

# %%
gdf.head()
# Out:
#                        country code  \
# 0                         Fiji  FJI
# 1  United Republic of Tanzania  TZA
# 2               Western Sahara  SAH
# 3                       Canada  CAN
# 4     United States of America  USA
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %%
df.drop(['country'], axis=1, inplace=True)
df.head()
# Out:
#   code  year  share_adults_obese
# 0  AFG  1975                 0.5
# 1  AFG  1976                 0.5
# 2  AFG  1977                 0.6
# 3  AFG  1978                 0.6
# 4  AFG  1979                 0.6

# %%
gdf = gdf.merge(df)

# %%
gdf.head()
# Out:
#   country code                                           geometry  year  \
# 0    Fiji  FJI  (POLYGON ((180 -16.06713266364245, 180 -16.555...  1975
# 1    Fiji  FJI  (POLYGON ((180 -16.06713266364245, 180 -16.555...  1976
# 2    Fiji  FJI  (POLYGON ((180 -16.06713266364245, 180 -16.555...  1977
# 3    Fiji  FJI  (POLYGON ((180 -16.06713266364245, 180 -16.555...  1978
# 4    Fiji  FJI  (POLYGON ((180 -16.06713266364245, 180 -16.555...  1979
#
#    share_adults_obese
# 0                 9.5
# 1                 9.8
# 2                10.1
# 3                10.5
# 4                10.8

# %%
datos_1980 = gdf[gdf.year == 1980]
datos_1980.head()
# Out:
#                          country code  \
# 5                           Fiji  FJI
# 47   United Republic of Tanzania  TZA
# 89                        Canada  CAN
# 131     United States of America  USA
# 173                   Kazakhstan  KAZ
#
#                                               geometry  year  \
# 5    (POLYGON ((180 -16.06713266364245, 180 -16.555...  1980
# 47   POLYGON ((33.90371119710453 -0.950000000000000...  1980
# 89   (POLYGON ((-122.84 49.00000000000011, -122.974...  1980
# 131  (POLYGON ((-122.84 49.00000000000011, -120 49....  1980
# 173  POLYGON ((87.35997033076265 49.21498078062912,...  1980
#
#      share_adults_obese
# 5                  11.2
# 47                  1.2
# 89                 11.3
# 131                13.7
# 173                 7.9

# %%
datos_1980.plot(column='share_adults_obese', legend=True)

# %%
gdf[gdf.year == 1990].plot(column='share_adults_obese')

# %%
data_1980 = gdf[gdf.year == 1980]
data_1990 = gdf[gdf.year == 1990]
data_2000 = gdf[gdf.year == 2000]
data_2010 = gdf[gdf.year == 2010]

# %%
fig, ax = plt.subplots(nrows=2,ncols=2, sharex=True, sharey=True)
data_1980.plot(ax=ax[0][0], column='share_adults_obese', legend=True)
data_1990.plot(ax=ax[0][1], column='share_adults_obese', legend=True)
data_2000.plot(ax=ax[1][0], column='share_adults_obese', legend=True)
data_2010.plot(ax=ax[1][1], column='share_adults_obese', legend=True)

# %%
data_1980.plot(column='share_adults_obese', legend=True, cmap="Greens")

# %%
data_1990.plot(column='share_adults_obese', legend=True, cmap="Greens")

# %%
data_2000.plot(column='share_adults_obese', legend=True, cmap="Greens")

# %%
data_2000[data_2000.code == 'MEX'].head()
# Out:
#     country code                                           geometry  year  \
# 949  Mexico  MEX  POLYGON ((-117.1277599999999 32.53533999999996...  2000
#
#      share_adults_obese
# 949                20.8

# %%
data_1990[data_1990.code == 'MEX'].head()
# Out:
#     country code                                           geometry  year  \
# 939  Mexico  MEX  POLYGON ((-117.1277599999999 32.53533999999996...  1990
#
#      share_adults_obese
# 939                15.9

# %%
fig, ax = plt.subplots(nrows=3, sharex=True, sharey=True)
data_1990.plot(ax=ax[0], column='share_adults_obese', legend=True)
data_2000.plot(ax=ax[1], column='share_adults_obese', legend=True)
data_2010.plot(ax=ax[2], column='share_adults_obese', legend=True)

# %%
df[(df.code == 'MEX') & ((df.year == 2000) | (df.year == 2010)| (df.year == 1990))]
# Out:
#      code  year  share_adults_obese
# 4803  MEX  1990                15.9
# 4813  MEX  2000                20.8
# 4823  MEX  2010                25.8
